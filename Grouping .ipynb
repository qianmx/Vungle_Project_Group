# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
# %pylab inline

from datetime import datetime,timedelta
import json
import re

from collections import OrderedDict
from math import pi
import pytz
import time
import psycopg2
from sqlalchemy import create_engine

from scipy import stats
import csv

from sklearn.decomposition import PCA
from sklearn.preprocessing import scale, normalize
import seaborn.apionly as sns
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_csv('balanced_data.csv')
# Out:
# /Users/amiee/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.shape
# Out:
# (700000, 27)

# %%
data.ix[0,:]
# Out:
# advertiser_app_store_id                                  1009442510
# country_code                                                     CN
# city                                                            NaN
# campaign_id                                56fc3b248409c5677800005c
# creative_id                                582efacc4156ab1024000034
# device_language                                                  zh
# device_make                                                   iPad3
# device_model                                                      4
# device_platform                                                 iOS
# device_connection                                              wifi
# device_os_version                                              10.2
# device_screen_height                                           2048
# device_screen_width                                            1536
# device_volume                                                 0.375
# event_id                                   58674105bdf48743587bdde6
# n_campaign_views                                                  4
# n_vungle_installs                                                 0
# publisher_app_store_id                     5255b9a777aa478519000008
# time_of_last_delivery_this_campaign             2016-12-29 11:09:20
# time_of_last_delivery_this_creative             2016-12-29 10:09:03
# time_of_last_delivery_any_installed_app                         NaN
# time_of_last_vungle_delivery                    2016-12-31 04:53:51
# time_of_this_impression                         2016-12-31 11:18:39
# timestamp_at_install                                            NaN
# time_of_this_request                            2016-12-31 05:24:16
# time_zone                                             Asia/Shanghai
# is_install                                                        0
# Name: 0, dtype: object

# %% [markdown]
# ### Convert timestamps to date format

# %%
cols = ['time_of_last_delivery_this_campaign', 'time_of_last_delivery_this_creative', 'time_of_last_delivery_any_installed_app',
       'time_of_last_delivery_any_installed_app','time_of_last_vungle_delivery', 'time_of_this_impression','time_of_this_request']
for col in cols:
#     print col
    name = col + "_date"
    data[name] = data[col].apply(lambda x: pd.to_datetime(x).date())
# Out:
# time_of_last_delivery_this_campaign
# time_of_last_delivery_this_creative
# time_of_last_delivery_any_installed_app
# time_of_last_delivery_any_installed_app
# time_of_last_vungle_delivery
# time_of_this_impression
# time_of_this_request

# %% [markdown]
# ### get continent info from time zone

# %%
def get_continent(x):
    if len(str(x).split('/')) > 1:
        return str(x).split('/')[0]
    else:
        return None

# %%
data['time_zone_continent'] = data['time_zone'].apply(lambda x: get_continent(x))

# %% [markdown]
# ### standardize the format of device_language

# %%
data['device_language'] = data['device_language'].apply(lambda x: str(x).lower().split('-')[0])

# %% [markdown]
# ### grouping insignificant data (sig level = 0.95)

# %%
def new_col_sig95(df, col):
    sig_level = 0.05
    df = df.copy()
    items = df[col].unique()
    for i in items:
        a = df[df[col] == i]['is_install']
        b = df[df[col] != i]['is_install']
        t, p = stats.ttest_ind(a, b, equal_var=False)
        if p >= sig_level:
            df[col][df[col] == i] = 'other'
    return df[col]

# %%
data.ix[0,:]
# Out:
# advertiser_app_store_id                                       1009442510
# country_code                                                          CN
# city                                                                 NaN
# campaign_id                                     56fc3b248409c5677800005c
# creative_id                                     582efacc4156ab1024000034
# device_language                                                       zh
# device_make                                                        iPad3
# device_model                                                           4
# device_platform                                                      iOS
# device_connection                                                   wifi
# device_os_version                                                   10.2
# device_screen_height                                                2048
# device_screen_width                                                 1536
# device_volume                                                      0.375
# event_id                                        58674105bdf48743587bdde6
# n_campaign_views                                                       4
# n_vungle_installs                                                      0
# publisher_app_store_id                          5255b9a777aa478519000008
# time_of_last_delivery_this_campaign                  2016-12-29 11:09:20
# time_of_last_delivery_this_creative                  2016-12-29 10:09:03
# time_of_last_delivery_any_installed_app                              NaN
# time_of_last_vungle_delivery                         2016-12-31 04:53:51
# time_of_this_impression                              2016-12-31 11:18:39
# timestamp_at_install                                                 NaN
# time_of_this_request                                 2016-12-31 05:24:16
# time_zone                                                  Asia/Shanghai
# is_install                                                             0
# time_of_last_delivery_this_campaign_date                      2016-12-29
# time_of_last_delivery_this_creative_date                      2016-12-29
# time_of_last_delivery_any_installed_app_date                         NaT
# time_zone_continent                                                 Asia
# time_of_last_vungle_delivery_date                             2016-12-31
# time_of_this_impression_date                                  2016-12-31
# time_of_this_request_date                                     2016-12-31
# Name: 0, dtype: object

# %%
cols = ['advertiser_app_store_id', 'country_code', 'device_language', 'device_platform',
       'device_connection', 'time_zone_continent']
for col in cols:
#     print col
    name = col + '_95'
    data[name] = new_col_sig95(data, col)
# Out:
# advertiser_app_store_id
# /Users/amiee/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/amiee/anaconda2/lib/python2.7/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# country_code
# device_language
# device_platform
# device_connection
# n_campaign_views
# time_zone_continent

# %%
data
# Out:
#                        advertiser_app_store_id country_code city  \
# 0                                   1009442510           CN  NaN
# 1                     5743f032a5a36ff4300000a5           ID  NaN
# 2                                    727296976           CA  NaN
# 3                     57a28ffbb019f8257c00021d           LA  NaN
# 4                          com.plarium.vikings           CZ  NaN
# 5                     558bdb44bbed958866000191           CN  NaN
# 6                            com.skout.android           BR  NaN
# 7                     58534782688691e41e000011           US  NaN
# 8                     585215f054dbb89701000ba2           US  NaN
# 9                                    937718942           US  NaN
# 10                    57e43b208b2389dd16000014           MX  NaN
# 11                    57a0c2d7b019f8257c00018e           US  NaN
# 12                                   667728512           CA  NaN
# 13                                   739699649           CH  NaN
# 14                    56f408588818291e76000187           IL  NaN
# 15                          net.peakgames.amy1           US  NaN
# 16                    575555f0e410603d0b0000cb           US  NaN
# 17                                   828578246           US  NaN
# 18                    57d912ef259d5ca21800002e           CN  NaN
# 19                    57bacc8f04d458e01d00012d           IN  NaN
# 20                    54878e91603bda157c000036           RO  NaN
# 21                    5743f032a5a36ff4300000a5           JP  NaN
# 22                    5743f032a5a36ff4300000a5           BR  NaN
# 23                    571e55363c9196512b0000d5           US  NaN
# 24                    5629f8988c69a37b08000098           FR  NaN
# 25                    57e43b208b2389dd16000014           EC  NaN
# 26                    577578f207f4a3db5b0002ef           US  NaN
# 27                    54878e91603bda157c000036           US  NaN
# 28                                   890378044           GB  NaN
# 29                    585215f054dbb89701000ba2           US  NaN
# ...                                        ...          ...  ...
# 699970                               767473889           US  NaN
# 699971                5774a02f3b5e53d05b000239           GB  NaN
# 699972                          com.rovio.baba           DE  NaN
# 699973                574d7342839628243f0000e3           GB  NaN
# 699974                584e46d58be0b6d40e0002b8           KR  NaN
# 699975  com.episodeinteractive.android.catalog           ES  NaN
# 699976                564a3534bdbd8d7e6700000c           US  NaN
# 27      56002dc680fbbf102800010c  5643e8c6c3d2fc511500000f              en
# 28      582f8908740cf4426b1d18b9  585d6f3cb7fb4fb67d00003d              en
# 29      585247d492f308b72a00015a  5860bace91bcf915650001e9              en
# ...                          ...                       ...             ...
# 699970  54bd4dfccf5a03891e0000a9  585751ccf38a011a3c000361              en
# 699971  585a40af7478409b3e00014c  584657dceee6c2d26900006c              en
# 699972  583fba697db01d1961000349  583a3daf01da2e3a750000d9              de
# 699973  57a8937fce348df748000052  58588ae0051b4079220001fb              en
# 699974  58541563f38a011a3c000162  58541b90febcab143c000225              ko
# 699975  567490a3ca2744f863000013  57fe6912c29d8069220000b1              es
# 699976  564bb4dad98ef03c36000011  57f5bc007d0516272700010a              es
# 699977  54113513cd4847e52400002b  57fc528e07d3dfed55000062              en
# 699978  584f6836494c28e44a00023b  56a7e6cb2f9d0e56690000d1              es
# 699979  5852465b0bf5c2e15500014f  5860bace91bcf915650001e9              en
# 699980  58089cd9083a09f92800009e  584a9183bed880de4a00002c              zh
# 699981  581a0eae5b1da4a66c00003d  58465caf6dea79c175000078              it
# 699982  584a20dea389cb6c03000015  585a31921c99e567220001f4              es
# 699983  584a788fdcccd37803000015  584657dceee6c2d26900006c              en
# 699984  5800fd6b5cbb9fa52600002e  584657dceee6c2d26900006c              da
# 699985  56cc9f30adffb0465b0002fd  5848cde37d9bba4622000146              en
# 699986  5696da1386c608c0020000d7  5722045311fcc3827e0000df              ru
# 699987  5768630af2f07ebf5c0000b8  584dfd68bed880de4a0000d4              en
# 699988  583fba697db01d1961000349  583a3daf01da2e3a750000d9              en
# 699989  58198f4f1111045d3400006f  5761acbb032b4e476f000078              es
# 699990  56fc3b248409c5677800005c  582ef65f9b9001390e00003d              zh
# 699991  5808984e083a09f92800009b  581978ff45242ab16c000039              fr
# 699992  5853f8293adda7a60c000024  586125432d0c82392e0002b0              en
# 699993  5853f8293adda7a60c000024  5860c91d156bf31f650001b0              en
# 699994  5853f8293adda7a60c000024  5860c91d156bf31f650001b0              en
# 699995  58580e0349704450630005c0  585be882a41b0d391e000189              en
# 699996  57fbd20d2f53d4432c00000d  5843e71cc975a3d07d000032              en
# 699997  584916070dacbe2e220000ea  585167c5685030b84c00008e              fr
# 699998  564bb4dad98ef03c36000011  56c37230ad1609a7230000bd              en
# 699999  564bb4dad98ef03c36000011  57f5bc007d0516272700010a              en
#
#        device_make              device_model device_platform  \
# 0            iPad3                         4             iOS
# 1           LENOVO              Lenovo A6010         android
# 2            iPad6                         3             iOS
# 3          iPhone7                         2             iOS
# 4           Archos  Archos 55 diamond Selfie         android
# 5          iPhone7                         2             iOS
# 6             asus                ASUS_Z00VD         android
# 7          iPhone8                         2             iOS
# 8          samsung                  SM-T357T         android
# 9            iPad3                         4             iOS
# 10         samsung                   SM-T530         android
# 11         iPhone8                         4             iOS
# 12         iPhone6                         1             iOS
# 13         iPhone8                         1             iOS
# 14         samsung                  SM-J7108         android
# 15             LGE                   LGMS330         android
# 16         samsung                  SM-G550T         android
# 17         iPhone7                         2             iOS
# 18           iPad5                         3             iOS
# 19            LAVA                 Pixel V2+         android
# 20         iPhone5                         2             iOS
# 21            Sony                    SO-04H         android
# 22         samsung                 SM-G360BT         android
# 23          YIFANG                 NX008HD8G         android
# 24         samsung                  SM-G386F         android
# 25         samsung                  SM-G925I         android
# 26         samsung                   SM-T350         android
# 27         iPhone6                         1             iOS
# 28         iPhone8                         1             iOS
# 29         samsung                  SM-G920P         android
# ...            ...                       ...             ...
# 699970     iPhone7                         2             iOS
# 699971     iPhone8                         1             iOS
# 699972     samsung                   SM-T550         android
# 699973     iPhone6                         2             iOS
# 699974     samsung                  SM-G930S         android
# 699975    Vodafone                   VFD 600         android
# 699976     samsung                 SM-G550T1         android
# 699977     iPhone8                         1             iOS
# 699978     samsung                  SM-G925F         android
# 699979     samsung                 SM-G930W8         android
# 699980     samsung                  SM-G9287         android
# 699981       CUBOT                       X12         android
# 699982     samsung                  SM-G531H         android
# 699983     iPhone7                         2             iOS
# 699984     iPhone8                         1             iOS
# 699985     samsung                   SM-T113         android
# 699986     iPhone7                         2             iOS
# 699987     samsung                 SM-T560NU         android
# 699988   hipstreet                    8DTB38         android
# 699989       iPad2                         2             iOS
# 699990       iPad6                         7             iOS
# 699991     samsung                  SM-G935F         android
# 699992     iPhone8                         2             iOS
# 699993     iPhone5                         3             iOS
# 699994     iPhone8                         1             iOS
# 699995     iPhone9                         3             iOS
# 699996     iPhone7                         2             iOS
# 699997     samsung                  SM-G925F         android
# 699998     samsung          SAMSUNG-SM-N910A         android
# 699999     samsung                  SM-G928T         android
#
#        device_connection          ...            \
# 0                   wifi          ...
# 1                 mobile          ...
# 2                   wifi          ...
# 3                 mobile          ...
# 4                   wifi          ...
# 5                    NaN          ...
# 6                   wifi          ...
# 7                    NaN          ...
# 8                   wifi          ...
# 9                   wifi          ...
# 10                  wifi          ...
# 11                  wifi          ...
# 12                  wifi          ...
# 13                mobile          ...
# 14                  wifi          ...
# 15                  wifi          ...
# 16                  wifi          ...
# 17                mobile          ...
# 18                  wifi          ...
# 19                  wifi          ...
# 20                  wifi          ...
# 21                  wifi          ...
# 22                mobile          ...
# 23                  wifi          ...
# 24                  wifi          ...
# 25                mobile          ...
# 26                  wifi          ...
# 27                mobile          ...
# 28                mobile          ...
# 29                mobile          ...
# ...                  ...          ...
# 699970              wifi          ...
# 699971              wifi          ...
# 699972              wifi          ...
# 699973              wifi          ...
# 699974            mobile          ...
# 699975              wifi          ...
# 699976            mobile          ...
# 699977            mobile          ...
# 699978              wifi          ...
# 699979              wifi          ...
# 699980            mobile          ...
# 699981              wifi          ...
# 699982              wifi          ...
# 699983              wifi          ...
# 699984              wifi          ...
# 699985              wifi          ...
# 699986              wifi          ...
# 699987              wifi          ...
# 699988              wifi          ...
# 699989              wifi          ...
# 699990               NaN          ...
# 699991              wifi          ...
# 699992            mobile          ...
# 699993              wifi          ...
# 699994              wifi          ...
# 699995              wifi          ...
# 699996              wifi          ...
# 699997              wifi          ...
# 699998            mobile          ...
# 699999            mobile          ...
#
#        time_of_last_vungle_delivery_date  time_of_this_impression_date  \
# 0                             2016-12-31                    2016-12-31
# 24                  FR                  fr             android
# 25                  EC                  es             android
# 26                  US                  en             android
# 27                  US                  en                 iOS
# 28                  GB                  en                 iOS
# 29                  US                  en             android
# ...                ...                 ...                 ...
# 699970              US                  en                 iOS
# 699971              GB                  en                 iOS
# 699972              DE                  de             android
# 699973              GB                  en                 iOS
# 699974              KR                  ko             android
# 699975              ES                  es             android
# 699976              US                  es             android
# 699977              US                  en                 iOS
# 699978              SE                  es             android
# 699979              CA                  en             android
# 699980              TW                  zh             android
# 699981              IT                  it             android
# 699982              CL                  es             android
# 699983              US                  en                 iOS
# 699984              DK                  da                 iOS
# 699985              US                  en             android
# 699986              RU                  ru                 iOS
# 699987              US                  en             android
# 699988              GB                  en             android
# 699989              VE                  es                 iOS
# 699990              CN                  zh                 iOS
# 699991              FR                  fr             android
# 699992              US                  en                 iOS
# 699993              US                  en                 iOS
# 699994              US                  en                 iOS
# 699995              US                  en                 iOS
# 699996              AU                  en                 iOS
# 699997              FR                  fr             android
# 699998              US                  en             android
# 699999              US                  en             android
#
#        device_connection_95 n_campaign_views_95 time_zone_continent_95
# 0                      wifi                   4                   Asia
# 1                    mobile                   0                   Asia
# 2                      wifi                   0                America
# 3                    mobile                   1                   Asia
# 4                      wifi                   0                 Europe
# 5                       NaN                   0                   Asia
# 6                      wifi                   0                America
# 7                       NaN                   1                America
# 8                      wifi                   8                America
# 9                      wifi                   2                America
# 10                     wifi                   7                America
# 11                     wifi                   1                America
# 12                     wifi                   0                America
# 13                   mobile                   8                 Europe
# 14                     wifi                   3                   Asia
# 15                     wifi                   3                America
# 16                     wifi                   0                America
# 17                   mobile                   0                America
# 18                     wifi                   0                   Asia
# 19                     wifi                   1                   Asia
# 20                     wifi                   0                 Europe
# 21                     wifi                   0                   Asia
# 22                   mobile                   3                America
# 23                     wifi                   0                America
# 24                     wifi                   1                 Europe
# 25                   mobile                   2                America
# 26                     wifi                   0                America
# 27                   mobile                   0                America
# 28                   mobile                   2                 Europe
# 29                   mobile                   1                America
# ...                     ...                 ...                    ...
# 699970                 wifi                   0                America
# 699971                 wifi                   0                 Europe
# 699972                 wifi                   0                 Europe
# 699973                 wifi                   0                 Europe
# 699974               mobile                   2                   Asia
# 699975                 wifi                   6                 Europe
# 699976               mobile                   0                America
# 699977               mobile                   0                America
# 699978                 wifi                   0                 Europe
# 699979                 wifi                   0                America
# 699980               mobile                   1                   Asia
# 699981                 wifi                   0                 Europe
# 699982                 wifi                   2                America
# 699983                 wifi                   5                America
# 699984                 wifi                   0                 Europe
# 699985                 wifi                   0                America
# 699986                 wifi                   0                 Europe
# 699987                 wifi                   0                America
# 699988                 wifi                   0                 Europe
# 699989                 wifi                   1                America
# 699990                  NaN                   0                   Asia
# 699991                 wifi                   0                 Europe
# 699992               mobile                   0                America
# 699993                 wifi                   0                America
# 699994                 wifi                   1                America
# 699995                 wifi                   0                America
# 699996                 wifi                   0              Australia
# 699997                 wifi                   0                 Europe
# 699998               mobile                   0                America
# 699999               mobile                   0                America
#
# [700000 rows x 41 columns]

# %%
data.to_csv('balanced_data_grouped.csv')
